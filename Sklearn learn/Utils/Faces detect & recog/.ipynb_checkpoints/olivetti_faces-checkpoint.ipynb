# %%
from sklearn import datasets
import matplotlib.pyplot as plt

faces = datasets.fetch_olivetti_faces()
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /home/liberio/scikit_learn_data

# %%
faces.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'DESCR'])

# %%
faces.images.shape
# Out:
# (400, 64, 64)

# %%
img = faces.images[0]
plt.imshow(img, cmap='gray')

# %%
plt.imshow(img[:30,:30])

# %%
plt.imshow(faces.images[10])

# %%
def visual_multi(idx_start,n=10):
    n_plot = n
    fig=plt.figure(figsize=[8,5])
    for j in range(n_plot):
        plt.subplot(5,5,j+1)
        plt.imshow(faces.images[
            idx_start+j
        ], cmap='gray')
        plt.title(faces.target[
            idx_start+j
        ])
        plt.axis('off')
plt.show()

# %%
visual_multi(50,20)
#plt.savefig('faces.jpg')
