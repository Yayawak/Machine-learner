# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
G = nx.lollipop_graph(4,6)
pathlengths = []

for v in G.nodes():
    spl = dict(nx.single_source_shortest_path_length(G, v))
    # print(f'{v} : {spl}')
    for p in spl:
        pathlengths.append(p)

print()
print(f'shortest path length {sum(pathlengths) / len(pathlengths)}')

# histogram of path lengths
dist = {}
for p in pathlengths:
    if p in dist:
        dist[p] += 1
    else:
        dist[p] = 1

pos = nx.spring_layout(G, seed=3056) # seed = fixed to the same 
nx.draw(G, pos=pos, with_labels=True)
# Out:
# shortest path length 4.5

# %%
G = nx.Graph()
G.add_node(1)

G.add_nodes_from(range(0, 3))

G.add_nodes_from([
   (4, {'color':'red'}) ,
   (5, {'color':'green'}) ,
])
nx.draw(G)

# %%
H = nx.path_graph(20)
G.add_nodes_from(H)
nx.draw(G)

# %%
G.add_node(H)
nx.draw(G)

# %%
G = nx.Graph(test_g='hello')
G.add_nodes_from(range(5))

G.add_edge(1,2)
e = (3,1)
G.add_edge(*e)

G.add_edges_from([(1,3), (3,5)])

G.add_node('spam')
G.add_nodes_from('killx')
nx.draw(G)

# %%
list(G.nodes)
# Out:
# [0, 1, 2, 3, 4, 5, 'spam', 'k', 'i', 'l', 'x']

# %%
list(G.edges)
# Out:
# [(1, 2), (1, 3), (3, 5)]

# %%
H = nx.DiGraph(G)
nx.draw(H)

# %%
G = nx.Graph()
G.add_node(1, time='5am')
G.add_nodes_from([3], time='2pm')
G.nodes
# Out:
# NodeView((1, 3))

# %%
G.nodes[1]
# Out:
# {'time': '5am'}

# %%
G.nodes[1]['room'] = 851
G.nodes.data()
# Out:
# NodeDataView({1: {'time': '5am', 'room': 851}, 3: {'time': '2pm'}})

# %%
DG = nx.DiGraph() # graph with Arrow
DG.add_weighted_edges_from([(1, 2, 0.5*10), (3, 1, 0.75)])
DG.out_degree(1, weight='weight')

DG.degree(1, weight='weight')

# list(DG.successors(1))

# list(DG.neighbors(1))
nx.draw(DG)

# %%
MG = nx.MultiGraph()
MG.add_weighted_edges_from([(1, 2, 0.5), (1, 2, 0.75), (2, 3, 0.5)])
dict(MG.degree(weight='weight'))

GG = nx.Graph()
for n, nbrs in MG.adjacency():
   for nbr, edict in nbrs.items():
       minvalue = min([d['weight'] for d in edict.values()])
       GG.add_edge(n, nbr, weight = minvalue)

nx.shortest_path(GG, 1, 3)

nx.draw(GG)
nx.draw(MG)

# %%
K_5 = nx.complete_graph(5)
K_3_5 = nx.complete_bipartite_graph(3, 5)
barbell = nx.barbell_graph(10, 10)
lollipop = nx.lollipop_graph(10, 20)

# %%
nx.draw(K_5)

# %%
nx.draw(K_3_5)

# %%
nx.draw(barbell)

# %%
nx.draw(lollipop)

# %%
G = nx.petersen_graph()
subax1 = plt.subplot(121)
nx.draw(G, with_labels=True, )
subax2 = plt.subplot(122)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')

plt.show()

# %%
options = {
    'node_color': 'black',
    'node_size': 100,
    'width': 3,
}
subax1 = plt.subplot(221)
nx.draw_random(G, **options)
subax2 = plt.subplot(222)
nx.draw_circular(G, **options)
subax3 = plt.subplot(223)
nx.draw_spectral(G, **options)
subax4 = plt.subplot(224)
nx.draw_shell(G, nlist=[range(5,10), range(5)], **options)
